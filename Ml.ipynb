# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("/Users/saurabhkannaujia/MachineLearning/cybersecurity_intrusion_data.csv")
print(df.shape)
print(df.head(5))
# Out:
# (9537, 11)
#   session_id  network_packet_size protocol_type  login_attempts  \
# 0  SID_00001                  599           TCP               4
# 1  SID_00002                  472           TCP               3
# 2  SID_00003                  629           TCP               3
# 3  SID_00004                  804           UDP               4
# 4  SID_00005                  453           TCP               5
#
#    session_duration encryption_used  ip_reputation_score  failed_logins  \
# 0        492.983263             DES             0.606818              1
# 1       1557.996461             DES             0.301569              0
# 2         75.044262             DES             0.739164              2
# 3        601.248835             DES             0.123267              0
# 4        532.540888             AES             0.054874              1
#
#   browser_type  unusual_time_access  attack_detected
# 0         Edge                    0                1
# 1      Firefox                    0                0
# 2       Chrome                    0                1
# 3      Unknown                    0                1
# 4      Firefox                    0                0

# %%
df_label = df.copy() # Creating a copy of the original dataframe
le= LabelEncoder() # Initializing LabelEncoder

df_label["protocol_type_Encoderd"]=le.fit_transform(df_label["protocol_type"]) # Encoding the 'protocol_type' column
print("\nLabel Encoderd Data")
print(df_label[["protocol_type_Encoderd","protocol_type"]].head()) # Displaying the first 5 rows of the encoded and original columns
# Out:
# Label Encoderd Data
#    protocol_type_Encoderd protocol_type
# 0                       1           TCP
# 1                       1           TCP
# 2                       1           TCP
# 3                       2           UDP
# 4                       1           TCP

# %%
df.isnull().sum()
# Out:
# session_id                0
# network_packet_size       0
# protocol_type             0
# login_attempts            0
# session_duration          0
# encryption_used        1966
# ip_reputation_score       0
# failed_logins             0
# browser_type              0
# unusual_time_access       0
# attack_detected           0
# dtype: int64

# %%
df["encryption_used"].fillna(df["encryption_used"].mode()[0],inplace=True)
print(df["encryption_used"])
# Out:
# 0       DES
# 1       DES
# 2       DES
# 3       DES
# 4       AES
#        ...
# 9532    AES
# 9533    AES
# 9534    AES
# 9535    AES
# 9536    AES
# Name: encryption_used, Length: 9537, dtype: object
# /var/folders/g4/4f2dft7d6d1_s999fn2p83500000gn/T/ipykernel_4066/2701942542.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["encryption_used"].fillna(df["encryption_used"].mode()[0],inplace=True)

# %%
df.isnull().mean() * 100.  # how many percentage of data is missing in each column
# Out:
# session_id             0.0
# network_packet_size    0.0
# protocol_type          0.0
# login_attempts         0.0
# session_duration       0.0
# encryption_used        0.0
# ip_reputation_score    0.0
# failed_logins          0.0
# browser_type           0.0
# unusual_time_access    0.0
# attack_detected        0.0
# dtype: float64

# %%
data=pd.read_csv("Cybersecurity Incidents and Data Breaches 2024.csv")
print(data.head())
# Out:
#   Incident_ID Date_Reported          Company_Name    Industry         Country  \
# 0     CYB_001    2024-01-15  HealthTech Solutions  Healthcare   United States
# 1     CYB_002    2024-01-22       GlobalBank Corp   Financial  United Kingdom
# 2     CYB_003    2024-02-03       EduPlatform Inc   Education          Canada
# 3     CYB_004    2024-02-14       RetailGiant Ltd      Retail       Australia
# 4     CYB_005    2024-02-28       TechStartup Pro  Technology         Germany
#
#       Attack_Type  Records_Compromised      Attack_Vector  \
# 0      Ransomware              2400000     Phishing_Email
# 1     Data_Breach               890000      SQL_Injection
# 2      Ransomware               567000      Remote_Access
# 3   Payment_Fraud              1200000      Card_Skimming
# 4  Insider_Threat                45000  Privileged_Access
#
#       Data_Types_Stolen  Ransom_Amount_USD  ...  Patch_Status  MFA_Enabled  \
# 0     PII,PHI,Financial                2.5  ...      Outdated           No
# 1         Financial,PII                0.0  ...       Current          Yes
# 2  PII,Academic_Records                1.2  ...      Outdated           No
# 3     Payment_Cards,PII                0.0  ...       Current      Partial
# 4      IP,Customer_Data                0.0  ...       Current          Yes
#
#   Security_Training_Hours  Incident_Severity      Attribution  \
# 0                       8           Critical            APT29
# 1                      24               High          Unknown
# 2                       4               High            Conti
# 3                      12               High  Organized_Crime
# 4                      16             Medium         Employee
#
#    Response_Time_Hours Regulatory_Fine_Million_USD Stock_Impact_Percent  \
# 0                   72                         8.5                -12.3
# 1                   12                        15.2                 -8.7
# 2                   96                         2.1                 -5.4
# 3                    6                         0.0                 -3.2
# 4                   24                         0.0                 -1.8
#
#    Customer_Churn_Percent Reputation_Score_Change
# 0                    15.2                     -25
# 1                     8.9                     -18
# 2                    12.1                     -15
# 3                     6.7                      -8
# 4                     3.4                      -5
#
# [5 rows x 26 columns]

# %%
data_label = data.copy() # Creating a copy of the original dataframe
le = LabelEncoder() # Initializing LabelEncoder
data_label["MFA_Enabled_Encoded"] = le.fit_transform(data_label["MFA_Enabled"]) # fit_transform means to fit the encoder and transform the data in one step
print('\nLabel Encoded data')
print(data_label[["MFA_Enabled", "MFA_Enabled_Encoded"]].head(10))
# Out:
# Label Encoded data
#   MFA_Enabled  MFA_Enabled_Encoded
# 0          No                    0
# 1         Yes                    2
# 2          No                    0
# 3     Partial                    1
# 4         Yes                    2
# 5         Yes                    2
# 6          No                    0
# 7         Yes                    2
# 8     Partial                    1
# 9          No                    0

# %%
df_encoded = pd.get_dummies(data, columns=["Industry"]) # get_dummies means converting categorical variable into binary 

print("\nOne-Hot Encoded Data")
print(df_encoded.head())
# Out:
# One-Hot Encoded Data
#   Incident_ID Date_Reported          Company_Name         Country  \
# 0     CYB_001    2024-01-15  HealthTech Solutions   United States
# 1     CYB_002    2024-01-22       GlobalBank Corp  United Kingdom
# 2     CYB_003    2024-02-03       EduPlatform Inc          Canada
# 3     CYB_004    2024-02-14       RetailGiant Ltd       Australia
# 4     CYB_005    2024-02-28       TechStartup Pro         Germany
#
#       Attack_Type  Records_Compromised      Attack_Vector  \
# 0      Ransomware              2400000     Phishing_Email
# 1     Data_Breach               890000      SQL_Injection
# 2      Ransomware               567000      Remote_Access
# 3   Payment_Fraud              1200000      Card_Skimming
# 4  Insider_Threat                45000  Privileged_Access
#
#       Data_Types_Stolen  Ransom_Amount_USD  Recovery_Time_Days  ...  \
# 0     PII,PHI,Financial                2.5                  45  ...
# 1         Financial,PII                0.0                  21  ...
# 2  PII,Academic_Records                1.2                  18  ...
# 3     Payment_Cards,PII                0.0                   8  ...
# 4      IP,Customer_Data                0.0                   5  ...
#
#    Industry_Hospitality Industry_Insurance  Industry_Legal  \
# 0                 False              False           False
# 1                 False              False           False
# 2                 False              False           False
# 3                 False              False           False
# 4                 False              False           False
#
#    Industry_Manufacturing  Industry_Pharmaceutical Industry_Real Estate  \
# 0                   False                    False                False
# 1                   False                    False                False
# 2                   False                    False                False
# 3                   False                    False                False
# 4                   False                    False                False
#
#   Industry_Retail  Industry_Technology Industry_Telecommunications  \
# 0           False                False                       False
# 1           False                False                       False
# 2           False                False                       False
# 3            True                False                       False
# 4           False                 True                       False
#
#   Industry_Transportation
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 43 columns]
